# %% [markdown]
# # <center>Laboratorium Analiza i bazy danych </center>
#
# ## <center>Łączenie tabel, podzapytania i funkcje agregujące</center>

# %% [markdown]
# ## Przykładowe tabele obrazujące łączenie
#
# Do zobrazowania operacji łączenia zostaną użyte tabele:
#
# ```sql
# CREATE TABLE shape_a (
#     id INT PRIMARY KEY,
#     shape VARCHAR (100) NOT NULL
# );
#
# CREATE TABLE shape_b (
#     id INT PRIMARY KEY,
#     shape VARCHAR (100) NOT NULL
# );
# ```
#
# Polecenie CREATE TABLE tworzy tabelę o zadanej nazwie i strukturze. Ogólna postać to:
# ```sql
# CREATE TABLE tab_name (
#     col_name1 data_type constrain,
#     col_name1 data_type constrain,
#     ...
# );
# ```
# Należy uzupełnić ją danymi:
# ```sql
# INSERT INTO shape_a (id, shape)
# VALUES
#     (1, 'Trójkąt'),
#     (2, 'Kwadrat'),
#     (3, 'Deltoid'),
#     (4, 'Traper');
#
# INSERT INTO shape_b (id, shape)
# VALUES
#     (1, 'Kwadrat'),
#     (2, 'Trójkąt'),
#     (3, 'Romb'),
#     (4, 'Równoległobok');
# ```
# Komenda INSERT INTO pozwala na dodanie do tabeli rekordów. Ogólna postać to:
#
# ```sql
# INSERT INTO tab_name (col1_name, col2_name2, ...)
# VALUES
#     (val1_col1, val2_col2),
#     (val2_col1, val2_col2),
#     ...
# ```

# %% [markdown]
# ## Inner join
#
# Jest to podstawowy rodzaj złączenie. Ten sposób złączenia wybiera  te wiersze, dla których warunek złączenia jest spełniony. W żadnej z łączonych tabel kolumna użyta do łączenia nie może mieć wartości NULL.
#
# #### Przykład:
# ```sql
# SELECT
#     a.id id_a,
#     a.shape shape_a,
#     b.id id_b,
#     b.shape shape_b
# FROM
#     shape_a a
# INNER JOIN shape_b b ON a.shape = b.shape;
# ```
# W zapytaniu powyżej użyto *aliasów* nazw tabel i column wynikowych, jest to szczególnie przydatne przy długich nazwach tabel i wprowadza czytelność w zapytaniu.
#
# #### Wynik:
# |id_a|shape_a|id_b|shape_b|
# |-|-|-|-|
# |1|Trójkąt|2|Trójkąt|
# |2|Kwadrat|1|Kwadrat|

# %% [markdown]
# ## OUTER JOIN
#
# Istnieją trzy rodzaje złączeń OUTER:
# - LEFT OUTER JOIN,
# - RIGHT OUTER JOIN,
# - FULL OUTER JOIN.
#
# ### LEFT OUTER JOIN
#
# Ten rodzaj złączenie zwróci wszystkie rekordy z lewej tablicy i dopasuje do nich rekordy z prawej tablicy które spełniją zadany warunek złączenia. Jeżeli w prawej tablicy nie występują rekordy spełnijące warunek złączenia z lewą w ich miejscu pojawią się wartości NULL.
#
# #### Przykład 1:
# ```sql
# SELECT
#     a.id id_a,
#     a.shape shape_a,
#     b.id id_b,
#     b.shape shape_b
# FROM
#     shape_a a
# LEFT JOIN shape_b b ON a.shape = b.shape;
# ```
# #### Wynik:
# |id_a|shape_a|id_b|shape_b|
# |-|-|-|-|
# |1|Trójkąt|2|Trójkąt|
# |2|Kwadrat|1|Kwadrat|
# |3|Deltoid|NULL|NULL|
# |4|Traper|NULL|NULL|
#
# #### Przykład 2:
# ```sql
# SELECT
#     b.id id_b,
#     b.shape shape_b,
#     a.id id_a,
#     a.shape shape_a
# FROM
#     shape_b b
# LEFT JOIN shape_a a ON a.shape = b.shape;
# ```
# #### Wynik:
# |id_a|shape_a|id_b|shape_b|
# |-|-|-|-|
# |1|Kwadrat|2|Kwadrat|
# |2|Trójkąt|1|Trójkąt|
# |3|Romb|NULL|NULL|
# |4|Równoległobok|NULL|NULL|
#
# ### RIGHT OUTER JOIN
#
# Działa jak left outer join z tym, że prawa tablica w zapytaniu jest brana w całości.
#
# #### Przykład:
# ```sql
# SELECT
#     a.id id_a,
#     a.shape shape_a,
#     b.id id_b,
#     b.shape shape_b
# FROM
#     shape_a a
# RIGHT JOIN shape_b b ON a.shape = b.shape;
# ```
#
# #### Wynik:
# |id_a|shape_a|id_b|shape_b|
# |-|-|-|-|
# |2|Kwadrat|1|Kwadrat|
# |1|Trójkąt|2|Trójkąt|
# |NULL|NULL|3|Romb|
# |NULL|NULL|4|Równoległobok|
#
#
# ### FULL OUTER JOIN
#
# Jest złączeniem które zwraca:
# - wiersze dla których warunek złączenia jest spełniony,
# - wiersze z lewej tabeli dla których nie ma odpowiedników w prawej,
# - wiersze z prawej tabeli dla których nie ma odpowiedników w lewej.
#
# #### Przykład:
# ```sql
# SELECT
#     a.id id_a,
#     a.shape shape_a,
#     b.id id_b,
#     b.shape shape_b
# FROM
#     shape_a a
# FULL JOIN shape_b b ON a.shape = b.shape;
# ```
# |id_a|shape_a|id_b|shape_b|
# |-|-|-|-|
# |1|Trójkąt|2|Trójkąt|
# |2|Kwadrat|1|Kwadrat|
# |3|Deltoid"|NULL|NULL|
# |4|Traper|NULL|NULL|
# |NULL|NULL|3|Romb|
# |NULL|NULL|4|Równoległobok|

# %% [markdown]
# ## Podzapytania
#
# Podzapytanie zagnieżdżone SELECT znajduje się wewnątrz zewnętrznego zapytania SELECT, np. po klauzuli WHERE, HAVING lub FROM. W przypadku tego rodzaju zapytań w pierwszej kolejności wykonywane są wewnętrzne zapytania SELECT, a ich wynik jest wykorzystywany do zewnętrznego zapytania SELECT. Stąd łatwo zuważyć, że mogą one służyć do poprawy wydajności obsługi zapytania. Należy dobierać podzapytania tak by najbardziej zagnieżdżone podzapytanie zawierało najmniejszy zbiór poszukiwań.
#
# #### Przykład:
# Jeżeli chcemy znaleźć w bazie informację o tytułach filmów zwróconych w zadanym okresie możemy wykonać następujące zapytanie:
# ```sql
# SELECT
#    film_id,
#    title
# FROM
#    film
# WHERE
#    film_id IN (
#       SELECT
#          inventory.film_id
#       FROM
#          rental
#       INNER JOIN inventory ON inventory.inventory_id = rental.inventory_id
#       WHERE
#          return_date BETWEEN '2005-05-29'
#       AND '2005-05-30'
#    );
# ```
#
# #### Wynik
# |film_id|title|
# |-|-|
# |307|Fellowship Autumn|
# |255|Driving Polish|
# |388|Gunfight Moon|
# |130|Celebrity Horn|
# |563|Massacre Usual|
# |397|Hanky October|
# |...|...|
#
# ### Używanie podzapytań
#
# Pod zapytania mogą być używane w :
# - SELECT,
# - UPDATE,
# - DELETE,
# - Funkcjach agregujących,
# - Do definiowania tabel tymczasowych.
#
# Używając podzapytań zapytania SQL szybko mogą stać się mało czytelne. Przez co będą trudne w zrozumieniu i późniejszym utrzymaniu. W celu analizy zapytań można użyć klauzuli __EXPLAIN__, która przeanalizuje zapytanie. Klauzula ta może służyć również do porównywania wydajności zapytań
#
# #### Przykład:
# ```sql
# EXPLAIN SELECT
#    *
# FROM
#    film
# ```

# %% [markdown]
# ## Funkcje agregujące
#
# Funkcje agregujące wykonują obliczenia na zestawie wierszy i zwracają pojedynczy wiersz. PostgreSQL udostępnia wszystkie standardowe funkcje agregujące SQL w następujący sposób:
# - AVG () - zwraca średnią wartość.
# - COUNT () - zwraca liczbę wartości.
# - MAX () - zwraca maksymalną wartość.
# - MIN () - zwraca minimalną wartość.
# - SUM () - zwraca sumę wszystkich lub różnych wartości.
#
# Pełna lista funkcji agregującej: https://www.postgresql.org/docs/9.5/functions-aggregate.html
#
# Często używamy funkcji agregujących z klauzulą GROUP BY w instrukcji SELECT. W tych przypadkach klauzula GROUP BY dzieli zestaw wyników na grupy wierszy i funkcja agregująca wykonuje obliczenia dla każdej grupy, np. maksimum, minimum, średnia itp. Funkcji agregujących można używać funkcji agregujących jako wyrażeń tylko w następujących klauzulach: SELECT i HAVING.
#
# ### GROUP BY
# Klauzula GROUP BY dzieli wiersze zwrócone z instrukcji SELECT na grupy. Dla  każdej grupy można zastosować funkcję agregującą, np. SUM aby obliczyć sumę pozycji lub
# COUNT aby uzyskać liczbę elementów w grupach.
#
# Poniższa instrukcja ilustruje składnię klauzuli GROUP BY:
# ```sql
# SELECT
#     column_1,
#     aggregate_function(column_2)
# FROM
#     tbl_name
# GROUP BY
#     column_1;
# ```
# Klauzula GROUP BY musi pojawić się zaraz po klauzuli FROM lub WHERE, n0astępnie GROUP BY zawiera listę  kolumna oddzielonych przecinkami.
#
# ### HAVING
# Często używamy klauzuli HAVING w połączeniu z klauzulą GROUP BY do filtrowania wierszy grup
# które nie spełniają określonego warunku.
#
# Poniższa instrukcja ilustruje typową składnię klauzuli HAVING:
# ```sql
# SELECT
#     column_1,
#     aggregate_function (column_2)
# FROM
#     tbl_name
# GROUP BY
#     column_1
# HAVING
#     condition;
# ```
# Klauzula HAVING ustawia warunek dla wierszy grup utworzonych przez klauzulę GROUP BY.
#
# Klauzula GROUP BY ma zastosowanie, podczas gdy klauzula WHERE określa wcześniej warunki dla poszczególnych wierszy.

# %% [markdown]
# ## Zadania wprowadzające
# Wykonaj zapytania przy użyciu DBMS:
#
# 1. Znajdź listę wszystkich filmów o tej samej długości.
# 2. Znajdź wszystkich klientów mieszkających w tym samym mieście.
# 3. Oblicz średni koszt wypożyczenia wszystkich filmów.
# 4. Oblicz i wyświetl liczbę filmów we wszystkich kategoriach.
# 5. Wyświetl liczbę wszystkich klientów pogrupowanych według kraju.
# 6. Wyświetl informacje o sklepie, który ma więcej niż 100 klientów i mniej niż 300 klientów.
# 7. Wybierz wszystkich klientów, którzy oglądali filmy ponad 200 godzin.
# 8. Oblicz średnią wartość wypożyczenia filmu.
# 9. Oblicz średnią wartość długości filmu we wszystkich kategoriach.
# 10. Znajdź najdłuższe tytuły filmowe we wszystkich kategoriach.
# 11. Znajdź najdłuższy film we wszystkich kategoriach. Porównaj wynik z pkt 10.

# %%
import psycopg2 as pg
import pandas as pd

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# **Zadanie 1** Znajdź listę wszystkich filmów o tej samej długości.

# %%
df = pd.read_sql('\
SELECT length, COUNT(film_id) "number of films" FROM film \
GROUP BY length \
ORDER BY length ASC \
',con=connection)
print(df)
# Out:
#      length  number of films
# 0        46                5
# 1        47                7
# 2        48               11
# 3        49                5
# 4        50                9
# 5        51                7
# 6        52                7
# 7        53                9
# 8        54                6
# 9        55                2
# 10       56                5
# 11       57                7
# 12       58                7
# 13       59                9
# 14       60                8
# 15       61               10
# 16       62                6
# 17       63                9
# 18       64                9
# 19       65                7
# 20       66                2
# 21       67                8
# 22       68                5
# 23       69                6
# 24       70                7
# 25       71                7
# 26       72                4
# 27       73               12
# 28       74               12
# 29       75               10
# 30       76                7
# 31       77                6
# 32       78                6
# 33       79                6
# 34       80               10
# 35       81                3
# 36       82                7
# 37       83                6
# 38       84               13
# 39       85               17
# 40       86                5
# 41       87                6
# 42       88                4
# 43       89                6
# 44       90                5
# 45       91                6
# 46       92               11
# 47       93                8
# 48       94                4
# 49       95                2
# 50       96                2
# 51       97                4
# 52       98                8
# 53       99                8
# 54      100               12
# 55      101                7
# 56      102               11
# 57      103                9
# 58      104                6
# 59      105                6
# 60      106                6
# 61      107               10
# 62      108                5
# 63      109                7
# 64      110                9
# 65      111                7
# 66      112               13
# 67      113                8
# 68      114               10
# 69      115                7
# 70      116                4
# 71      117                5
# 72      118                8
# 73      119                6
# 74      120                9
# 75      121                8
# 76      122               11
# 77      123                7
# 78      124                4
# 79      125                7
# 80      126                9
# 81      127                5
# 82      128                7
# 83      129                7
# 84      130                6
# 85      131                5
# 86      132                8
# 87      133                5
# 88      134                5
# 89      135               10
# 90      136                9
# 91      137                9
# 92      138                6
# 93      139               11
# 94      140                5
# 95      141                7
# 96      142                7
# 97      143                7
# 98      144                8
# 99      145                7
# 100     146                5
# 101     147                9
# 102     148                7
# 103     149                6
# 104     150                8
# 105     151                7
# 106     152                9
# 107     153                9
# 108     154                7
# 109     155                6
# 110     156                4
# 111     157                6
# 112     158                6
# 113     159                6
# 114     160                6
# 115     161                9
# 116     162                5
# 117     163                7
# 118     164                4
# 119     165                5
# 120     166                5
# 121     167                7
# 122     168                4
# 123     169                6
# 124     170                4
# 125     171                8
# 126     172                8
# 127     173                7
# 128     174                6
# 129     175                6
# 130     176               10
# 131     177                6
# 132     178               10
# 133     179               13
# 134     180                7
# 135     181               10
# 136     182                6
# 137     183                5
# 138     184                8
# 139     185               10
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 2** Znajdź wszystkich klientów mieszkających w tym samym mieście.

# %%
df = pd.read_sql('\
SELECT c.city, COUNT(cu.customer_id) "customers" FROM customer cu \
INNER JOIN address a ON a.address_id = cu.address_id \
INNER JOIN city c ON c.city_id = a.city_id \
GROUP BY c.city \
ORDER BY c.city \
',con=connection)
print(df)
# Out:
#                            city  customers
# 0            A Corua (La Corua)          1
# 1                          Abha          1
# 2                     Abu Dhabi          1
# 3                          Acua          1
# 4                         Adana          1
# 5                   Addis Abeba          1
# 6                          Aden          1
# 7                         Adoni          1
# 8                    Ahmadnagar          1
# 9                      Akishima          1
# 10                        Akron          1
# 11                       al-Ayn          1
# 12                  Alessandria          1
# 13                    al-Hawiya          1
# 14        Allappuzha (Alleppey)          1
# 15                      Allende          1
# 16                    al-Manama          1
# 17              Almirante Brown          1
# 18                   al-Qadarif          1
# 19                     al-Qatif          1
# 20                     Alvorada          1
# 21                     Ambattur          1
# 22                   Amersfoort          1
# 23                       Amroha          1
# 24               Angra dos Reis          1
# 25                      Anpolis          1
# 26                  Antofagasta          1
# 27          Aparecida de Goinia          1
# 28                    Apeldoorn          1
# 29                     Araatuba          1
# 30                         Arak          1
# 31                      Arecibo          1
# 32                    Arlington          1
# 33                       Ashdod          1
# 34                     Ashgabat          1
# 35                     Ashqelon          1
# 36                      Asuncin          1
# 37                      Athenai          1
# 38                       Atinsk          1
# 39                      Atlixco          1
# 40      Augusta-Richmond County          1
# 41                       Aurora          2
# 42                   Avellaneda          1
# 43                          Bag          1
# 44                  Baha Blanca          1
# 45                     Baicheng          1
# 46                       Baiyin          1
# 47                         Baku          1
# 48                      Balaiha          1
# 49                    Balikesir          1
# 50                    Balurghat          1
# 51                      Bamenda          1
# 52          Bandar Seri Begawan          1
# 53                       Banjul          1
# 54                    Barcelona          1
# 55                        Basel          1
# 56                      Bat Yam          1
# 57                       Batman          1
# 58                        Batna          1
# 59                   Battambang          1
# 60                       Baybay          1
# 61                      Bayugan          1
# 62                        Bchar          1
# 63                        Beira          1
# 64                     Bellevue          1
# 65                         Belm          1
# 66                     Benguela          1
# 67                  Beni-Mellal          1
# 68                   Benin City          1
# 69                      Bergamo          1
# 70      Berhampore (Baharampur)          1
# 71                         Bern          1
# 72                    Bhavnagar          1
# 73                     Bhilwara          1
# 74                   Bhimavaram          1
# 75                       Bhopal          1
# 76                     Bhusawal          1
# 77                      Bijapur          1
# 78                      Bilbays          1
# 79                      Binzhou          1
# 80                      Birgunj          1
# 81                       Bislig          1
# 82                     Blumenau          1
# 83                    Boa Vista          1
# 84                     Boksburg          1
# 85                     Botosani          1
# 86                   Botshabelo          1
# 87                     Bradford          1
# 88                      Braslia          1
# 89                   Bratislava          1
# 90                      Brescia          1
# 91                        Brest          1
# 92                     Brindisi          1
# 93                     Brockton          1
# 94                    Bucuresti          1
# 95                 Buenaventura          1
# 96                    Bydgoszcz          1
# 97                      Cabuyao          1
# 98                       Callao          1
# 99                     Cam Ranh          1
# 100                  Cape Coral          1
# 101                     Caracas          1
# 333                       Miraj          1
# 334                   Mit Ghamr          1
# 335                  Miyakonojo          1
# 336                    Mogiljov          1
# 337                   Molodetno          1
# 338                    Monclova          1
# 339                      Monywa          1
# 340                      Moscow          1
# 341                       Mosul          1
# 342                    Mukateve          1
# 343            Munger (Monghyr)          1
# 344                      Mwanza          1
# 345                  Mwene-Ditu          1
# 346                    Myingyan          1
# 347                      Mysore          1
# 348                 Naala-Porto          1
# 349           Nabereznyje Telny          1
# 350                       Nador          1
# 351                      Nagaon          1
# 352                  Nagareyama          1
# 353                   Najafabad          1
# 354                        Naju          1
# 355                Nakhon Sawan          1
# 356                    Nam Dinh          1
# 357                      Namibe          1
# 358                      Nantou          1
# 359                     Nanyang          1
# 360                     NDjamna          1
# 361                   Newcastle          1
# 362               Nezahualcyotl          1
# 363                   Nha Trang          1
# 364                  Niznekamsk          1
# 365                    Novi Sad          1
# 366                Novoterkassk          1
# 367                   Nukualofa          1
# 368                        Nuuk          1
# 369                       Nyeri          1
# 370             Ocumare del Tuy          1
# 371                   Ogbomosho          1
# 372                       Okara          1
# 373                     Okayama          1
# 374                     Okinawa          1
# 375                     Olomouc          1
# 376                    Omdurman          1
# 377                       Omiya          1
# 378                        Ondo          1
# 379                    Onomichi          1
# 380                      Oshawa          1
# 381                    Osmaniye          1
# 382                       ostka          1
# 383                        Otsu          1
# 384                        Oulu          1
# 385            Ourense (Orense)          1
# 386                         Owo          1
# 387                         Oyo          1
# 388                      Ozamis          1
# 389                       Paarl          1
# 390             Pachuca de Soto          1
# 391                    Pak Kret          1
# 392          Palghat (Palakkad)          1
# 393              Pangkal Pinang          1
# 394                     Papeete          1
# 395                    Parbhani          1
# 396                   Pathankot          1
# 397                     Patiala          1
# 398                      Patras          1
# 399                    Pavlodar          1
# 400                    Pemalang          1
# 401                      Peoria          1
# 402                     Pereira          1
# 403                  Phnom Penh          1
# 404                   Pingxiang          1
# 405                  Pjatigorsk          1
# 406                       Plock          1
# 407                          Po          1
# 408                       Ponce          1
# 409                   Pontianak          1
# 410              Poos de Caldas          1
# 411                  Portoviejo          1
# 412                 Probolinggo          1
# 413                 Pudukkottai          1
# 414                        Pune          1
# 415             Purnea (Purnia)          1
# 416                  Purwakarta          1
# 417                   Pyongyang          1
# 418                      Qalyub          1
# 419                 Qinhuangdao          1
# 420                     Qomsheh          1
# 421                     Quilmes          1
# 422                  Rae Bareli          1
# 423                      Rajkot          1
# 424                      Rampur          1
# 425                    Rancagua          1
# 426                      Ranchi          1
# 427               Richmond Hill          1
# 428                   Rio Claro          1
# 429                      Rizhao          1
# 430                     Roanoke          1
# 431                     Robamba          1
# 432                    Rockford          1
# 433                        Ruse          1
# 434                  Rustenburg          1
# 435                  Saarbrcken          1
# 436                  Sagamihara          1
# 437                 Saint Louis          1
# 438                 Saint-Denis          1
# 439                         Sal          1
# 440                      Salala          1
# 441                   Salamanca          1
# 442                     Salinas          1
# 443                    Salzburg          1
# 444                     Sambhal          1
# 445              San Bernardino          1
# 446  San Felipe de Puerto Plata          1
# 447     San Felipe del Progreso          1
# 448  San Juan Bautista Tuxtepec          1
# 449                 San Lorenzo          1
# 450        San Miguel de Tucumn          1
# 451                       Sanaa          1
# 452         Santa Brbara dOeste          1
# 453                     Santa F          1
# 454                  Santa Rosa          1
# 455      Santiago de Compostela          1
# 456  Santiago de los Caballeros          1
# 457                  Santo Andr          1
# 458                       Sanya          1
# 459                      Sasebo          1
# 460                       Satna          1
# 461                      Sawhaj          1
# 462                    Serpuhov          1
# 463                Shahr-e Kord          1
# 464                     Shanwei          1
# 465                    Shaoguan          1
# 466                      Sharja          1
# 467                    Shenzhen          1
# 468             s-Hertogenbosch          1
# 469                   Shikarpur          1
# 470                     Shimoga          1
# 471                 Shimonoseki          1
# 472                   Shivapuri          1
# 473            Shubra al-Khayma          1
# 474                      Siegen          1
# 475        Siliguri (Shiliguri)          1
# 476                  Simferopol          1
# 477                   Sincelejo          1
# 478                      Sirjan          1
# 479                       Sivas          1
# 480                      Skikda          1
# 481                    Smolensk          1
# 482        So Bernardo do Campo          1
# 483                 So Leopoldo          1
# 484                    Sogamoso          1
# 485                      Sokoto          1
# 486                    Songkhla          1
# 487                    Sorocaba          1
# 488                  Soshanguve          1
# 489                      Sousse          1
# 490                  South Hill          1
# 491                 Southampton          1
# 492             Southend-on-Sea          1
# 493                   Southport          1
# 494                     Springs          1
# 495                Stara Zagora          1
# 496            Sterling Heights          1
# 497                   Stockport          1
# 498                       Sucre          1
# 499                      Suihua          1
# 500                     Sullana          1
# 501                 Sultanbeyli          1
# 502                    Sumqayit          1
# 503                        Sumy          1
# 504               Sungai Petani          1
# 505                   Sunnyvale          1
# 506                   Surakarta          1
# 507                   Syktyvkar          1
# 508                    Syrakusa          1
# 509                 Szkesfehrvr          1
# 510                      Tabora          1
# 511                      Tabriz          1
# 512                       Tabuk          1
# 513                      Tafuna          1
# 514                      Taguig          1
# 515                       Taizz          1
# 516                    Talavera          1
# 517                 Tallahassee          1
# 518                        Tama          1
# 519                    Tambaram          1
# 520                     Tanauan          1
# 521                      Tandil          1
# 522                     Tangail          1
# 523                     Tanshui          1
# 524                       Tanza          1
# 525                      Tarlac          1
# 526                      Tarsus          1
# 527                       Tartu          1
# 528                   Teboksary          1
# 529                       Tegal          1
# 530              Tel Aviv-Jaffa          1
# 531                        Tete          1
# 532                     Tianjin          1
# 533                       Tiefa          1
# 534                       Tieli          1
# 535                       Tokat          1
# 536                     Tonghae          1
# 537                    Tongliao          1
# 538                      Torren          1
# 539                      Touliu          1
# 540                      Toulon          1
# 541                    Toulouse          1
# 542                     Trshavn          1
# 543                     Tsaotun          1
# 544                     Tsuyama          1
# 545                  Tuguegarao          1
# 546                       Tychy          1
# 547                     Udaipur          1
# 548                       Udine          1
# 549                        Ueda          1
# 550                    Uijongbu          1
# 551                    Uluberia          1
# 552                       Urawa          1
# 553                     Uruapan          1
# 554                        Usak          1
# 555           Usolje-Sibirskoje          1
# 556           Uttarpara-Kotrung          1
# 557                       Vaduz          1
# 558                    Valencia          1
# 559          Valle de la Pascua          1
# 560           Valle de Santiago          1
# 561                    Valparai          1
# 562                   Vancouver          1
# 563          Varanasi (Benares)          1
# 564                Vicente Lpez          1
# 565                  Vijayawada          1
# 566                  Vila Velha          1
# 567                     Vilnius          1
# 568                        Vinh          1
# 569        Vitria de Santo Anto          1
# 570                      Warren          1
# 571                     Weifang          1
# 572                      Witten          1
# 573                     Wroclaw          1
# 574                    Xiangfan          1
# 575                    Xiangtan          1
# 576                      Xintai          1
# 577                    Xinxiang          1
# 578                Yamuna Nagar          1
# 579                      Yangor          1
# 580                      Yantai          1
# 581                      Yaound          1
# 582                     Yerevan          1
# 583                    Yinchuan          1
# 584                     Yingkou          1
# 585                        York          1
# 586                    Yuncheng          1
# 587                      Yuzhou          1
# 588                    Zalantun          1
# 589                    Zanzibar          1
# 590                     Zaoyang          1
# 591                     Zapopan          1
# 592                       Zaria          1
# 593                Zeleznogorsk          1
# 594                 Zhezqazghan          1
# 595                    Zhoushan          1
# 596                  Ziguinchor          1
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 3** Oblicz średni koszt wypożyczenia wszystkich filmów.

# %%
# Średnia zapłata przy pożyczaniu danego filmu
# df = pd.read_sql('\
# SELECT f.film_id, f.title, AVG(p.amount) "average rental cost" FROM rental r \
# INNER JOIN inventory i ON i.inventory_id = r.inventory_id \
# INNER JOIN film f ON f.film_id = i.film_id \
# INNER JOIN payment p ON p.rental_id = r.rental_id \
# GROUP BY f.film_id \
# ORDER BY f.film_id \
# ',con=connection)
# print(df)

df = pd.read_sql('\
SELECT AVG(amount) "Average cost of film rental" FROM payment \
',con=connection)
print(df)
# Out:
#    Average cost of film rental
# 0                     4.200606
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 4** Oblicz i wyświetl liczbę filmów we wszystkich kategoriach.

# %%
df = pd.read_sql('\
SELECT c.name category, COUNT(f.film_id) "number of films" FROM film f \
INNER JOIN film_category fc ON fc.film_id = f.film_id \
INNER JOIN category c ON c.category_id = fc.category_id \
GROUP BY category \
ORDER BY category ASC\
',con=connection)
print(df)
# Out:
#        category  number of films
# 0        Action               64
# 1     Animation               66
# 2      Children               60
# 3      Classics               57
# 4        Comedy               58
# 5   Documentary               68
# 6         Drama               62
# 7        Family               69
# 8       Foreign               73
# 9         Games               61
# 10       Horror               56
# 11        Music               51
# 12          New               63
# 13       Sci-Fi               61
# 14       Sports               74
# 15       Travel               57
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 5** Wyświetl liczbę wszystkich klientów pogrupowanych według kraju.

# %%
df = pd.read_sql('\
SELECT co.country, COUNT(cu.customer_id) "customers" FROM customer cu \
INNER JOIN address a ON a.address_id = cu.address_id \
INNER JOIN city ci ON ci.city_id = a.city_id \
INNER JOIN country co ON co.country_id = ci.country_id \
GROUP BY co.country \
ORDER BY customers DESC, co.country\
',con=connection)
print(df)
# Out:
#                                    country  customers
# 0                                    India         60
# 1                                    China         53
# 2                            United States         36
# 3                                    Japan         31
# 4                                   Mexico         30
# 5                                   Brazil         28
# 6                       Russian Federation         28
# 7                              Philippines         20
# 8                                   Turkey         15
# 9                                Indonesia         14
# 10                               Argentina         13
# 11                                 Nigeria         13
# 12                            South Africa         11
# 13                                  Taiwan         10
# 14                          United Kingdom          9
# 15                                    Iran          8
# 16                                  Poland          8
# 17                                 Germany          7
# 18                                   Italy          7
# 19                               Venezuela          7
# 20                                Colombia          6
# 21                                   Egypt          6
# 22                                 Ukraine          6
# 23                                 Vietnam          6
# 24                                  Canada          5
# 25                             Netherlands          5
# 26                                Pakistan          5
# 27                            Saudi Arabia          5
# 28                             South Korea          5
# 29                                   Spain          5
# 30                                  France          4
# 31                                  Israel          4
# 32                                    Peru          4
# 33                                   Yemen          4
# 34                                 Algeria          3
# 35                                 Austria          3
# 36                              Bangladesh          3
# 37                                   Chile          3
# 38                      Dominican Republic          3
# 39                                 Ecuador          3
# 40                                Malaysia          3
# 41                                 Morocco          3
# 42                              Mozambique          3
# 43                                Paraguay          3
# 44                             Switzerland          3
# 45                                Tanzania          3
# 46                                Thailand          3
# 47                    United Arab Emirates          3
# 48                                  Angola          2
# 49                              Azerbaijan          2
# 50                                 Belarus          2
# 51                                 Bolivia          2
# 52                                Bulgaria          2
# 53                                Cambodia          2
# 54                                Cameroon          2
# 55   Congo, The Democratic Republic of the          2
# 56                        French Polynesia          2
# 57                                  Greece          2
# 58                               Kazakstan          2
# 59                                   Kenya          2
# 60                                  Latvia          2
# 61                                 Myanmar          2
# 62                                    Oman          2
# 63                             Puerto Rico          2
# 64                                 Romania          2
# 65                                   Sudan          2
# 66                              Yugoslavia          2
# 67                             Afghanistan          1
# 68                          American Samoa          1
# 69                                Anguilla          1
# 70                                 Armenia          1
# 71                                 Bahrain          1
# 72                                  Brunei          1
# 73                                    Chad          1
# 74                          Czech Republic          1
# 75                                 Estonia          1
# 76                                Ethiopia          1
# 77                           Faroe Islands          1
# 78                                 Finland          1
# 79                           French Guiana          1
# 80                                  Gambia          1
# 81                               Greenland          1
# 82           Holy See (Vatican City State)          1
# 83                               Hong Kong          1
# 84                                 Hungary          1
# 85                                    Iraq          1
# 86                                  Kuwait          1
# 87                           Liechtenstein          1
# 88                               Lithuania          1
# 89                              Madagascar          1
# 90                                  Malawi          1
# 91                                 Moldova          1
# 92                                   Nauru          1
# 93                                   Nepal          1
# 94                             New Zealand          1
# 95                             North Korea          1
# 96                                  Runion          1
# 97        Saint Vincent and the Grenadines          1
# 98                                 Senegal          1
# 99                                Slovakia          1
# 100                              Sri Lanka          1
# 101                                 Sweden          1
# 102                                  Tonga          1
# 103                                Tunisia          1
# 104                           Turkmenistan          1
# 105                                 Tuvalu          1
# 106                   Virgin Islands, U.S.          1
# 107                                 Zambia          1
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 6** Wyświetl informacje o sklepie, który ma więcej niż 100 klientów i mniej niż 300 klientów.

# %%
df = pd.read_sql('\
SELECT store.store_id ,COUNT(customer.customer_id) customers, \
staff.first_name "manager first name", staff.last_name "manager last name", \
address.address "store address", city.city, country.country FROM store \
INNER JOIN customer ON customer.store_id = store.store_id \
INNER JOIN staff ON staff.staff_id = store.manager_staff_id \
INNER JOIN address ON address.address_id = store.address_id \
INNER JOIN city ON address.city_id = city.city_id \
INNER JOIN country ON country.country_id = city.country_id \
GROUP BY store.store_id, staff.first_name, staff.last_name, address.address, city.city, country.country \
HAVING COUNT(customer.customer_id) > 100 AND COUNT(customer.customer_id) < 300\
',con=connection)
df
# Out:
#    store_id  customers manager first name manager last name  \
# 0         2        273                Jon          Stephens
#
#         store address       city    country
# 0  28 MySQL Boulevard  Woodridge  Australia

# %% [markdown]
# **Zadanie 7** Wybierz wszystkich klientów, którzy oglądali filmy ponad 200 godzin.

# %%
#Nie używam zagnieżdzonego SELECTa, żeby wyświetlić też czas oglądania
df = pd.read_sql('\
SELECT c.customer_id, c.first_name, c.last_name, SUM(f.length) "watching time (minutes)" FROM customer c \
INNER JOIN rental r ON r.customer_id = c.customer_id \
INNER JOIN inventory i ON i.inventory_id = r.inventory_id \
INNER JOIN film f ON f.film_id = i.film_id \
GROUP BY c.customer_id \
HAVING SUM(f.length) > 60*200 \
ORDER BY c.customer_id \
',con=connection)
print('Klienci ogladajacy ponad 200 godzin:\n',df)

df = pd.read_sql('\
SELECT c.customer_id, c.first_name, c.last_name, SUM(f.length)/60 "watching time (hours)" FROM customer c \
INNER JOIN rental r ON r.customer_id = c.customer_id \
INNER JOIN inventory i ON i.inventory_id = r.inventory_id \
INNER JOIN film f ON f.film_id = i.film_id \
GROUP BY c.customer_id \
HAVING SUM(f.length)/60 > 75 \
ORDER BY "watching time (hours)", c.customer_id \
',con=connection)
print('\nKlienci ogladajacy ponad 75 godzin:\n',df)
# Out:
# Klienci ogladajacy ponad 200 godzin:
#  Empty DataFrame
# Columns: [customer_id, first_name, last_name, watching time (minutes)]
# Index: []
#
# Klienci ogladajacy ponad 75 godzin:
#     customer_id first_name last_name  watching time (hours)
# 0          119     Sherry  Marshall                     76
# 1          178     Marion    Snyder                     76
# 2          380    Russell   Brinson                     77
# 3          236     Marcia      Dean                     78
# 4          144      Clara      Shaw                     80
# 5          469     Wesley      Bull                     80
# 6           75      Tammy   Sanders                     84
# 7          148    Eleanor      Hunt                     89
# 8          526       Karl      Seal                     89
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 8** Oblicz średnią wartość wypożyczenia filmu.<br>
# W mainie było pytanie o średnią wartość dla zadanej długości filmów, z przykładowej linijki wywnioskowałem, że chodzi o średnią kwotę jaką trzeba zapłacić za wypożyczenie filmów o tej długości za jeden film.<br>
# Tutaj jest pytanie o obliczenie dla wszystkich filmów, co pokryłoby się z zadaniem 3, dlatego w zadaniu obliczę średni rental_rate dla wszystkich filmów, wydaje mi się to najbardziej odpowiednie do pytania

# %%
df = pd.read_sql('\
SELECT AVG(rental_rate) "Average rental rate" FROM film\
',con=connection)
print(df)
# Out:
#    Average rental rate
# 0                 2.98

# %% [markdown]
# **Zadanie 9** Oblicz średnią wartość długości filmu we wszystkich kategoriach.

# %%
df = pd.read_sql('\
SELECT c.name category, AVG(f.length) "avg length (min)" from film f \
INNER JOIN film_category fc ON fc.film_id = f.film_id \
INNER JOIN category c ON c.category_id = fc.category_id \
GROUP BY category \
ORDER BY category \
',con=connection)
print(df)
# Out:
#        category  avg length (min)
# 0        Action        111.609375
# 1     Animation        111.015152
# 2      Children        109.800000
# 3      Classics        111.666667
# 4        Comedy        115.827586
# 5   Documentary        108.750000
# 6         Drama        120.838710
# 7        Family        114.782609
# 8       Foreign        121.698630
# 9         Games        127.836066
# 10       Horror        112.482143
# 11        Music        113.647059
# 12          New        111.126984
# 13       Sci-Fi        108.196721
# 14       Sports        128.202703
# 15       Travel        113.315789
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 10** Znajdź najdłuższe tytuły filmowe we wszystkich kategoriach. <br>
# W niektórych kategoriach więcej niż jeden tytuł jest najdłuższy <br>
# W zadaniu wykorzystałem zagnieżdżone zapytanie SELECT do stworzenia tablicy z pogrupowaną według *category_id* największą długością tytułu (max liczba znaków) <br>
# Następnie przyłączyłem do niej pasujący tytuł na podstawie *category_id* i tej największej ilości znaków

# %%
df = pd.read_sql('\
SELECT c.name category, f.title "longest title" FROM(\
    SELECT fc.category_id cid, MAX(LENGTH(f.title)) max from film f \
    INNER JOIN film_category fc ON fc.film_id = f.film_id \
    GROUP BY cid \
    ) AS subquery \
INNER JOIN category c ON c.category_id = subquery.cid \
INNER JOIN film_category fc ON fc.category_id = c.category_id \
INNER JOIN film f ON f.film_id = fc.film_id AND LENGTH(f.title) = subquery.max \
ORDER BY category, "longest title"\
',con=connection)
print(df)
# Out:
#        category                longest title
# 0        Action      Entrapment Satisfaction
# 1     Animation       Telemark Heartbreakers
# 2      Children         Heartbreakers Bright
# 3      Children         Microcosmos Paradise
# 4      Children         Sweethearts Suspects
# 5      Classics      Extraordinary Conquerer
# 6        Comedy      Trainspotting Strangers
# 7   Documentary       Deliverance Mulholland
# 8   Documentary       Intolerable Intentions
# 9         Drama       Goldfinger Sensibility
# 10       Family       Resurrection Silverado
# 11      Foreign         Ballroom Mockingbird
# 12      Foreign         Impossible Prejudice
# 13      Foreign         Reservoir Adaptation
# 14        Games        Bulworth Commandments
# 15        Games        Creatures Shakespeare
# 16       Horror  Arachnophobia Rollercoaster
# 17        Music       Confidential Interview
# 18          New        Flamingos Connecticut
# 19       Sci-Fi         Barbarella Streetcar
# 20       Sci-Fi         Cincinatti Whisperer
# 21       Sci-Fi         Silverado Goldfinger
# 22       Sci-Fi         Unforgiven Zoolander
# 23       Sci-Fi         Wonderland Christmas
# 24       Sports    Satisfaction Confidential
# 25       Travel      Desperate Trainspotting
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# **Zadanie 11** Znajdź najdłuższy film we wszystkich kategoriach. Porównaj wynik z pkt 10. <br> Wyniki różnią się tak jak powinny. Nauczyło mnie to, że MAX(string) zwraca nie najdłuższą wartość, a alfabetycznie ostatnią

# %%
df = pd.read_sql('\
SELECT c.name category, f.title "longest film", subquery.max "length (min)", subquery.max / CAST(60 AS float) "length (hours)" FROM(\
    SELECT fc.category_id cid, MAX(f.length) max from film f \
    INNER JOIN film_category fc ON fc.film_id = f.film_id \
    GROUP BY cid \
    ) AS subquery \
INNER JOIN category c ON c.category_id = subquery.cid \
INNER JOIN film_category fc ON fc.category_id = c.category_id \
INNER JOIN film f ON f.film_id = fc.film_id AND f.length = subquery.max \
ORDER BY category, "longest film"\
',con=connection)
print(df)
# Out:
#        category        longest film  length (min)  length (hours)
# 0        Action      Darn Forrester           185        3.083333
# 1        Action        Worst Banger           185        3.083333
# 2     Animation         Gangs Pride           185        3.083333
# 3     Animation        Pond Seattle           185        3.083333
# 4      Children         Fury Murder           178        2.966667
# 5      Children      Wrong Behavior           178        2.966667
# 6      Classics   Conspiracy Spirit           184        3.066667
# 7        Comedy      Control Anthem           185        3.083333
# 8   Documentary           Wife Turn           183        3.050000
# 9   Documentary      Young Language           183        3.050000
# 10        Drama       Jacket Frisco           181        3.016667
# 11       Family      King Evolution           184        3.066667
# 12      Foreign    Crystal Breaking           184        3.066667
# 13      Foreign      Sorority Queen           184        3.066667
# 14        Games       Chicago North           185        3.083333
# 15       Horror    Analyze Hoosiers           181        3.016667
# 16       Horror       Love Suicides           181        3.016667
# 17        Music           Home Pity           185        3.083333
# 18          New      Frontier Cabin           183        3.050000
# 19       Sci-Fi  Soldiers Evolution           185        3.083333
# 20       Sports     Smoochy Control           184        3.066667
# 21       Travel       Muscle Bright           185        3.083333
# 22       Travel   Sweet Brotherhood           185        3.083333

# %% [markdown]
# ## Zadanie implementacyjne
# Zaimplementuj wszystkie funkcje w pliku main.py zgodnie z opisem a następnie przetestuj je w notatniku.

# %%
import main

# %%
print(main.film_in_category(3))
# Out:
#                    title               languge  category
# 0    Backlash Undefeated  English               Children
# 1         Bear Graceland  English               Children
# 2           Beneath Rush  English               Children
# 3          Betrayed Rear  English               Children
# 4            Cabin Flash  English               Children
# 5       Casper Dragonfly  English               Children
# 6    Christmas Moonshine  English               Children
# 7           Circus Youth  English               Children
# 8     Clockwork Paradise  English               Children
# 9      Comancheros Enemy  English               Children
# 10       Crooked Frogmen  English               Children
# 11      Daughter Madigan  English               Children
# 12          Doctor Grail  English               Children
# 13      Empire Malkovich  English               Children
# 14          Fargo Gandhi  English               Children
# 15     Forever Candidate  English               Children
# 16       Full Flatliners  English               Children
# 17           Fury Murder  English               Children
# 18       Ghost Groundhog  English               Children
# 19        Giant Troopers  English               Children
# 20        Gorgeous Bingo  English               Children
# 21         Graduate Lord  English               Children
# 22          Hall Cassidy  English               Children
# 23  Heartbreakers Bright  English               Children
# 24   Hollywood Anonymous  English               Children
# 25    Holocaust Highball  English               Children
# 26       Idols Snatchers  English               Children
# 27      Invasion Cyclone  English               Children
# 28          Jersey Sassy  English               Children
# 29         Jumping Wrath  English               Children
# 30      Labyrinth League  English               Children
# 31       Language Cowboy  English               Children
# 32     Legally Secretary  English               Children
# 33        Magic Mallrats  English               Children
# 34          Maker Gables  English               Children
# 35  Microcosmos Paradise  English               Children
# 36            Model Fish  English               Children
# 37      Murder Antitrust  English               Children
# 38             Noon Papi  English               Children
# 39       Polish Brooklyn  English               Children
# 40          Robbers Joon  English               Children
# 41      Sabrina Midnight  English               Children
# 42           Santa Paris  English               Children
# 43         Scarface Bang  English               Children
# 44    Shepherd Midsummer  English               Children
# 45         Sister Freddy  English               Children
# 46       Splendor Patton  English               Children
# 47    Strangelove Desire  English               Children
# 48    Stranger Strangers  English               Children
# 49     Sundance Invasion  English               Children
# 50  Sweethearts Suspects  English               Children
# 51          Tequila Past  English               Children
# 52           Ties Hunger  English               Children
# 53         Tootsie Pilot  English               Children
# 54       Twisted Pirates  English               Children
# 55          Uptown Young  English               Children
# 56          Walls Artist  English               Children
# 57      Warlock Werewolf  English               Children
# 58        Wrong Behavior  English               Children
# 59     Zoolander Fiction  English               Children
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.number_films_in_category(3))
# Out:
#    category  count
# 0  Children     60
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.number_film_by_length(89,106))
# Out:
#     length  count
# 0       89      6
# 1       90      5
# 2       91      6
# 3       92     11
# 4       93      8
# 5       94      4
# 6       95      2
# 7       96      2
# 8       97      4
# 9       98      8
# 10      99      8
# 11     100     12
# 12     101      7
# 13     102     11
# 14     103      9
# 15     104      6
# 16     105      6
# 17     106      6
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.client_from_city('York'))
print()
print(main.client_from_city('Athenai'))
# Out:
#    city first_name last_name
# 0  York    Gilbert    Sledge
#
#       city first_name last_name
# 0  Athenai      Linda  Williams
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.avg_amount_by_length(48))
# Out:
#    length       avg
# 0      48  4.295389
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.client_by_sum_length(1265))
# Out:
#       first_name     last_name   sum
# 0          Brian         Wyman  1265
# 1        Antonio          Meek  1451
# 2          Leona        Obrien  1588
# 3      Katherine        Rivera  1615
# 4        Tiffany        Jordan  1667
# 5         Jerome        Kenyon  1679
# 6          Penny          Neal  1738
# 7         Lonnie        Tirado  1834
# 8         Dwight      Lombardi  1846
# 9         Johnny        Turpin  1846
# 10      Caroline        Bowman  1847
# 11         Allan       Cornish  1916
# 12         Lewis         Lyman  1933
# 13        Lester         Kraus  1943
# 14           Eva         Ramos  1945
# 15        Austin       Cintron  1961
# 16         Joann       Gardner  1963
# 17         Annie       Russell  1965
# 18      Jonathan   Scarborough  1984
# 19         Anita       Morales  1999
# 20        Eileen          Carr  2031
# 21       Kenneth        Gooden  2033
# 22         Wayne        Truong  2044
# 23         Floyd         Gandy  2063
# 24         Paula        Bryant  2084
# 25        Nellie       Garrett  2098
# 26       Vanessa          Sims  2103
# 27            Jo        Fowler  2107
# 28         Ruben         Geary  2107
# 29         Oscar        Aquino  2119
# 30        Nelson   Christenson  2119
# 31          Irma       Pearson  2128
# 32       Kristen        Chavez  2130
# 33           Kay      Caldwell  2133
# 34       Armando        Gruber  2142
# 35        Sheila         Wells  2148
# 36        Eugene     Culpepper  2158
# 37     Christina       Ramirez  2178
# 38      Jeanette        Greene  2197
# 39           Ann         Evans  2202
# 40          Rose        Howard  2208
# 41         Edith      Mcdonald  2210
# 42          Raul       Fortier  2212
# 43         Lloyd          Dowd  2231
# 44           Kim          Cruz  2236
# 45        Bonnie        Hughes  2241
# 46         Julio        Noland  2258
# 47          Kirk       Stclair  2258
# 48        Vernon         Chapa  2270
# 328       Brenda        Wright  3092
# 329      Bradley        Motley  3094
# 330      Gabriel        Harder  3097
# 331     Terrance         Roush  3100
# 332        Karen       Jackson  3103
# 333       Evelyn        Morgan  3104
# 334        Eddie        Tomlin  3104
# 335      Gilbert        Sledge  3107
# 336       Denise         Kelly  3109
# 337     Beatrice        Arnold  3112
# 338          Ben        Easter  3112
# 339         Beth      Franklin  3112
# 340      Michele         Grant  3113
# 341        Jaime       Nettles  3116
# 342       Amanda        Carter  3118
# 343         Jane       Bennett  3119
# 344      Lucille        Holmes  3124
# 345      Richard       Mccrary  3128
# 346       Steven        Curley  3130
# 347        Randy       Gaither  3132
# 348      Allison       Stanley  3135
# 349          Ian         Still  3136
# 350         Brad       Mccurdy  3145
# 351      Michael     Silverman  3145
# 352         Ruby    Washington  3145
# 353        Leroy    Bustamante  3154
# 354       Jordan     Archuleta  3159
# 355       Jessie         Banks  3159
# 356         Gene       Sanborn  3164
# 357       Gloria          Cook  3166
# 358      Clifton       Malcolm  3169
# 359        Cathy       Spencer  3170
# 360        Sonia       Gregory  3177
# 361        Ricky        Shelby  3178
# 362       Jennie         Terry  3184
# 363     Clifford        Bowens  3191
# 364       Tracey       Barrett  3192
# 365      Felicia        Sutton  3192
# 366     Clarence         Gamez  3193
# 367        Susan        Wilson  3208
# 368       Carole       Barnett  3215
# 369     Reginald        Kinder  3230
# 370          Jay          Robb  3233
# 371         Dale      Ratcliff  3235
# 372          Joe     Gilliland  3238
# 373        Byron           Box  3240
# 374         Rick        Mattox  3243
# 375        Joyce       Edwards  3244
# 376        Andre          Rapp  3252
# 377         Lucy       Wheeler  3252
# 378         Ross          Grey  3262
# 379          Ken       Prewitt  3262
# 380          Ted        Breaux  3263
# 381       Javier         Elrod  3263
# 382        Clyde        Tobias  3265
# 383        Amber         Dixon  3266
# 384        Erika          Pena  3266
# 385      Deborah        Walker  3272
# 386      Jeffery        Pinson  3274
# 387       Philip        Causey  3279
# 388     Theodore          Culp  3279
# 389       Nathan        Runyon  3282
# 390       Dustin      Gillette  3283
# 391         Nina          Soto  3284
# 392          Lee         Hawks  3286
# 393     Salvador          Teel  3296
# 394       Jimmie     Eggleston  3300
# 395       Edward         Baugh  3302
# 396       Joshua          Mark  3302
# 397         Kent     Arsenault  3305
# 398       Bessie      Morrison  3306
# 399          Guy      Brownlee  3309
# 400       Andrew         Purdy  3315
# 401       Esther      Crawford  3320
# 402         Erik       Guillen  3320
# 403        Derek       Blakely  3321
# 404        Jimmy      Schrader  3326
# 405         Dawn      Sullivan  3326
# 406        Terry       Carlson  3347
# 407       Ronald        Weiner  3354
# 408        Duane         Tubbs  3355
# 409     Danielle       Daniels  3358
# 410       Sandra        Martin  3360
# 411        Misty       Lambert  3366
# 412        Becky         Miles  3366
# 413         Dean         Sauer  3366
# 414      Theresa        Watson  3375
# 415         Olga       Jimenez  3381
# 416         Marc        Outlaw  3386
# 417       Joseph           Joy  3389
# 418    Nathaniel          Adam  3394
# 419         Todd           Tan  3398
# 420       Teresa        Rogers  3403
# 514          Jim           Rea  3749
# 515       Arnold        Havens  3752
# 516          Ana       Bradley  3760
# 517         Lois        Butler  3762
# 518        Sally        Pierce  3762
# 519        Mabel       Holland  3770
# 520      Zachary          Hite  3771
# 521     Florence         Woods  3775
# 522         Rosa      Reynolds  3779
# 523       Carrie        Porter  3790
# 524       Stacey    Montgomery  3791
# 525        Viola        Hanson  3794
# 526        Julie       Sanchez  3808
# 527        Ethel          Webb  3810
# 528        Helen        Harris  3818
# 529          Mae      Fletcher  3828
# 530       Morris      Mccarter  3829
# 531     Nicholas      Barfield  3836
# 532   Jacqueline          Long  3855
# 533         Alex       Gresham  3857
# 534         Neil        Renner  3879
# 535        Casey          Mena  3891
# 536       Leslie        Seward  3891
# 537      Bernice        Willis  3892
# 538      Crystal          Ford  3894
# 539       Minnie        Romero  3911
# 540     Marjorie        Tucker  3911
# 541         Ella        Oliver  3916
# 542         Mary         Smith  3916
# 543       Thelma        Murray  3921
# 544  Christopher         Greco  3930
# 545     Gertrude      Castillo  3936
# 546       Gordon        Allard  3938
# 547        Heidi        Larson  3941
# 548    Alexander       Fennell  3942
# 549        Frank      Waggoner  3948
# 550        Bobby      Boudreau  3960
# 551        Jorge      Olivares  3962
# 552       Margie          Wade  3965
# 553        Hazel        Warren  3970
# 554         Dave      Gardiner  3971
# 555        Tonya       Chapman  3972
# 556      Cynthia         Young  3973
# 557      Melissa          King  3977
# 558      Kristin      Johnston  3981
# 559        Roger   Quintanilla  3987
# 560     Rosemary       Schmidt  3988
# 561        Barry      Lovelace  3989
# 562        Elsie        Kelley  4014
# 563         Mike           Way  4023
# 564       Sherri        Rhodes  4030
# 565       Regina         Berry  4051
# 566        Tommy       Collazo  4051
# 567        Grace         Ellis  4060
# 568      Jessica          Hall  4150
# 569       Marsha       Douglas  4154
# 570     Michelle         Clark  4157
# 571      Brandon          Huey  4160
# 572        Naomi      Jennings  4164
# 573        Brett      Cornwell  4197
# 574        Steve     Mackenzie  4206
# 575        Harry          Arce  4222
# 576       Warren       Sherrod  4233
# 577       Martha      Gonzalez  4237
# 578         June       Carroll  4261
# 579       Curtis          Irby  4280
# 580       Rhonda       Kennedy  4307
# 581          Sue        Peters  4319
# 582        Louis         Leone  4333
# 583       Angela     Hernandez  4362
# 584       Janice          Ward  4366
# 585        Daisy         Bates  4369
# 586          Tim          Cary  4476
# 587        Diane       Collins  4514
# 588    Elizabeth         Brown  4531
# 589       Justin           Ngo  4550
# 590       Sherry      Marshall  4582
# 591       Marion        Snyder  4599
# 592      Russell       Brinson  4640
# 593       Marcia          Dean  4734
# 594       Wesley          Bull  4808
# 595        Clara          Shaw  4808
# 596        Tammy       Sanders  5065
# 597      Eleanor          Hunt  5360
# 598         Karl          Seal  5388
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(main.category_statistic_length('Action'))
print()
print(main.category_statistic_length('Children'))
# Out:
#   category         avg   sum  min  max
# 0   Action  111.609375  7143   47  185
#
#    category    avg   sum  min  max
# 0  Children  109.8  6588   46  178
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /home/kuba/anaconda3/envs/jakubbajek/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
